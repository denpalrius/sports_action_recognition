# %% [markdown]
# # Video Classification with a CNN-RNN Architecture

# %% [markdown]
# ## Dependencies

# %%
# !pip install kagglehub imutils --quiet
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os

from imutils import paths

import imageio
import cv2
from IPython.display import Image

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, top_k_accuracy_score, classification_report, confusion_matrix

import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.metrics import top_k_categorical_accuracy

import kagglehub

import warnings

# %% [markdown]
# ## Data Loading

# %% [markdown]
# Get Tensorflow Docs

# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Acquire subsampled version of the original UCF101 dataset

# %%
# !!wget -q https://github.com/sayakpaul/Action-Recognition-in-TensorFlow/releases/download/v1.0.0/ucf101_top5.tar.gz
# !tar xf ucf101_top5.tar.gz

# %% [markdown]
# Load the train and test datasets

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

print(f"Total videos for training: {len(train_df)}")
print(f"Total videos for testing: {len(test_df)}")

train_df.sample(10)
# Out:
# Total videos for training: 594
# Total videos for testing: 224
#                      video_name           tag
# 146  v_PlayingCello_g12_c02.avi  PlayingCello
# 383  v_ShavingBeard_g11_c04.avi  ShavingBeard
# 514   v_TennisSwing_g13_c04.avi   TennisSwing
# 354         v_Punch_g25_c03.avi         Punch
# 19    v_CricketShot_g10_c06.avi   CricketShot
# 182  v_PlayingCello_g17_c06.avi  PlayingCello
# 282         v_Punch_g14_c04.avi         Punch
# 457  v_ShavingBeard_g23_c01.avi  ShavingBeard
# 459  v_ShavingBeard_g23_c03.avi  ShavingBeard
# 378  v_ShavingBeard_g10_c06.avi  ShavingBeard

# %% [markdown]
# ## Hyperparameters

# %%
IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 100 # TODO: Use 100 for final training

MAX_SEQ_LENGTH = 20 # TODO: Check the distribution of the sequence lengths
NUM_FEATURES = 2048

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Review Video frame distribution

# %% [markdown]
# Count the number of frames for each video

# %%
def count_frames_per_video(video_paths, root_dir):
    frame_counts = []

    for path in video_paths:        
        video_path = os.path.join(root_dir, path)
        cap = cv2.VideoCapture(video_path)
        count = 0
        while cap.isOpened():
            ret, _ = cap.read()
            if not ret:
                break
            count += 1
        cap.release()
        frame_counts.append(count)

    return frame_counts

# %%
def visualize_frame_distribution(frame_counts):
    plt.figure(figsize=(8, 5))
    sns.violinplot(x=frame_counts)
    plt.title("Violin Plot of Frame Counts per Video")
    plt.xlabel("Number of Frames")
    plt.xlabel("Number of Frames")
    plt.show()

# %%
frame_counts = count_frames_per_video(train_df["video_name"].values, "train/")

# %% [markdown]
# Standard deviation of the frame counts

# %%
np.std(frame_counts)
# Out:
# 83.85490702997471

# %%
visualize_frame_distribution(frame_counts)

# %% [markdown]
# ### Video preprocessing utilities

# %% [markdown]
#  Function to resize the video frames to a square shape without distorting their content

# %%
def crop_center_square(frame):
    y, x = frame.shape[0:2]  # Get the height (y) and width (x) of the image
    min_dim = min(y, x)       # Find the smallest dimension (either height or width)
    start_x = (x // 2) - (min_dim // 2)  # Calculate the horizontal starting point for the crop
    start_y = (y // 2) - (min_dim // 2)  # Calculate the vertical starting point for the crop
    
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]  # Return the cropped square

# %% [markdown]
# Crop,resize, and reorder color channels

# %%
def load_and_preprocess_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame) # Crop center square
            frame = cv2.resize(frame, resize) # Resize the image (In this case to 224x224)
            frame = frame[:, :, [2, 1, 0]] # Reorder the color channels from OpenCV BGR to RGB
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
   
    return np.array(frames)

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# Using a pre-trained network to extract meaningful features from the extracted frames, the InceptionV3 model pretrained on ImageNet-1k dataset

# %%
def build_feature_extractor():
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")

# %%
feature_extractor = build_feature_extractor()

# %% [markdown]
# Encode the class labels as integers using the Keras StringLookup layer

# %%
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"])
)

class_vocab = label_processor.get_vocabulary()

print(f"Vocabulary: {class_vocab}")
# Out:
# Vocabulary: ['CricketShot', 'PlayingCello', 'Punch', 'ShavingBeard', 'TennisSwing']

# %% [markdown]
# label_processorExtract frame_features, frame_masks and labels
# - `frame_features` will contain extracted features per frame
# - `frame_masks` will contain booleans denoting if a timestep/frame is padded or not

# %% [markdown]
# Helper function to create masks and features for a single video

# %%
def create_video_mask_and_features(frames):
    frames = frames[None, ...]  # Add batch dimension
    video_length = min(MAX_SEQ_LENGTH, frames.shape[1])

    mask = np.zeros((1, MAX_SEQ_LENGTH), dtype="bool")
    features = np.zeros((1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    for j in range(video_length):
        features[0, j, :] = feature_extractor.predict(frames[:, j, :], verbose=0)
    mask[0, :video_length] = 1  # Set mask for valid frames

    return features, mask

# %% [markdown]
# Main function for video feature extraction

# %%
def extract_features_and_masks(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = keras.ops.convert_to_numpy(label_processor(df["tag"].values[..., None]))

    frame_masks = np.zeros((num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros((num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    for idx, video_path in enumerate(video_paths):
        frames = load_and_preprocess_video(os.path.join(root_dir, video_path))
        
        # Prepare masks and features for the current video
        features, mask = create_video_mask_and_features(frames)
        frame_features[idx] = features
        frame_masks[idx] = mask

    return (frame_features, frame_masks), labels

# %% [markdown]
# Extract the frame features, feature masks and labels for the `train` set

# %%
train_data, train_labels = extract_features_and_masks(train_df, "train")

# %% [markdown]
# Extract the frame features, feature masks and labels for the `test` set

# %%
test_data, test_labels = extract_features_and_masks(test_df, "test")

# %%
total_samples, frame_count, num_of_features = train_data[0].shape

print(f"""Frame features in train set: {train_data[0].shape} 
    → {total_samples} samples
    → {frame_count} frames per video
    → {num_of_features} features per frame
""")

total_samples, mask_count = train_data[1].shape
print(f"""Frame masks in train set: {train_data[1].shape} 
    → {total_samples} samples
    → {mask_count} masks per video
""")

print(f"Frame features in test set: {test_data[0].shape}")
print(f"Frame masks in test set: {test_data[1].shape}")
# Out:
# Frame features in train set: (594, 20, 2048)
#     → 594 samples
#     → 20 frames per video
#     → 2048 features per frame
#
# Frame masks in train set: (594, 20)
#     → 594 samples
#     → 20 masks per video
#
# Frame features in test set: (224, 20, 2048)
# Frame masks in test set: (224, 20)

# %% [markdown]
# ## Sequence Model Architecture

# %% [markdown]
# Recurrent Neural Network architecture with GRU (Gated Recurrent Unit) layers

# %%
def build_rnn_sequence_model():
    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    x = keras.layers.GRU(16, return_sequences=True)(frame_features_input, mask=mask_input)
    x = keras.layers.GRU(8)(x)
    x = keras.layers.Dropout(0.4)(x)
    # x = keras.layers.Dense(8, activation="relu")(x) # TODO: Experiment with the dense layers
    x = keras.layers.Dense(64, activation="relu")(x)
    x = keras.layers.Dense(32, activation="relu")(x)
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

    # TODO: Check with categorical_crossentropy
    
    adam = keras.optimizers.Adam(learning_rate=0.001)
    
    rnn_model.compile(
        loss="sparse_categorical_crossentropy", 
        optimizer=adam,
        metrics=["accuracy"]
    )
    
    return rnn_model

# %% [markdown]
# Build the model

# %%
rnn_seq_model = build_rnn_sequence_model()
rnn_seq_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 20, 2048)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, 20)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_2 (GRU)         │ (None, 20, 16)    │     99,168 │ input_layer_4[0]… │
# │                     │                   │            │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_3 (GRU)         │ (None, 8)         │        624 │ gru_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8)         │          0 │ gru_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │        576 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 32)        │      2,080 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 5)         │        165 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 102,613 (400.83 KB)
#  Trainable params: 102,613 (400.83 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model Training

# %% [markdown]
# Utility to run the experiment

# %%
def train_and_evaluate_model(weights_file_path=None, seq_model=None):
    checkpoint = ModelCheckpoint(
        weights_file_path,
        monitor="val_loss",
        mode="min",  # Save the model when the loss decreases (when model improves)
        save_weights_only=True,
        save_best_only=True,
        verbose=1,
    )

    # TODO: Return this
    early_stopping = EarlyStopping(
        monitor="val_loss", patience=5, restore_best_weights=True, verbose=1
    )

    # Train the model
    history = seq_model.fit(
        [train_data[0], train_data[1]],
        train_labels,
        validation_split=0.3,
        epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    # Load the best weights after training
    seq_model.load_weights(weights_file_path)

    # Evaluate the model on a test sample
    print("\nEvaluating the model...")
    _, accuracy = seq_model.evaluate([test_data[0], test_data[1]], test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return seq_model, history

# %% [markdown]
# Run the experiment

# %%
weights_file_path = "models/ckpt.rnn_model.weights.h5"

sequence_model, history = train_and_evaluate_model(weights_file_path, rnn_seq_model)
# Out:
# Epoch 1/100
# 10/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4016 - loss: 1.5312
# Epoch 1: val_loss improved from inf to 1.97258, saving model to models/ckpt.rnn_model.weights.h5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4240 - loss: 1.5062 - val_accuracy: 0.0000e+00 - val_loss: 1.9726
# Epoch 2/100
# 10/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5466 - loss: 1.2600
# Epoch 2: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5617 - loss: 1.2417 - val_accuracy: 0.0000e+00 - val_loss: 2.2725
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6940 - loss: 0.9984
# Epoch 3: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6924 - loss: 0.9980 - val_accuracy: 0.0000e+00 - val_loss: 2.7875
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7235 - loss: 0.8181
# Epoch 4: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7235 - loss: 0.8170 - val_accuracy: 0.0000e+00 - val_loss: 3.0783
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7068 - loss: 0.7417
# Epoch 5: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7093 - loss: 0.7377 - val_accuracy: 0.0000e+00 - val_loss: 3.3024
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7850 - loss: 0.6012
# Epoch 6: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7869 - loss: 0.5974 - val_accuracy: 0.0279 - val_loss: 3.4435
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8644 - loss: 0.4180
# Epoch 7: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8639 - loss: 0.4189 - val_accuracy: 0.0112 - val_loss: 3.7876
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9086 - loss: 0.3315
# Epoch 8: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9096 - loss: 0.3297 - val_accuracy: 0.2961 - val_loss: 3.6519
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9135 - loss: 0.2890
# Epoch 9: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9155 - loss: 0.2865 - val_accuracy: 0.3240 - val_loss: 3.9191
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9623 - loss: 0.1795
# Epoch 10: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9617 - loss: 0.1803 - val_accuracy: 0.2961 - val_loss: 4.3791
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9491 - loss: 0.1520
# Epoch 11: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9495 - loss: 0.1522 - val_accuracy: 0.3464 - val_loss: 4.5918
# Epoch 12/100
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9694 - loss: 0.1600
# Epoch 12: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9700 - loss: 0.1568 - val_accuracy: 0.2961 - val_loss: 5.2661
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9760 - loss: 0.1031
# Epoch 13: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9758 - loss: 0.1036 - val_accuracy: 0.3296 - val_loss: 5.2855
# Epoch 14/100
# 11/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9771 - loss: 0.0868
# Epoch 14: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9755 - loss: 0.0897 - val_accuracy: 0.3464 - val_loss: 5.4617
# Epoch 15/100
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9574 - loss: 0.0981
# Epoch 15: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9583 - loss: 0.0980 - val_accuracy: 0.3464 - val_loss: 5.6669
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9818 - loss: 0.0702
# Epoch 16: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9809 - loss: 0.0716 - val_accuracy: 0.3464 - val_loss: 5.7279
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.
val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9933 - loss: 0.0208 - val_accuracy: 0.3408 - val_loss: 9.6336
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9992 - loss: 0.0098
# Epoch 91: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9990 - loss: 0.0100 - val_accuracy: 0.3408 - val_loss: 9.5291
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9869 - loss: 0.0240
# Epoch 92: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9873 - loss: 0.0238 - val_accuracy: 0.3408 - val_loss: 9.7550
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9821 - loss: 0.0320
# Epoch 93: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9825 - loss: 0.0312 - val_accuracy: 0.3408 - val_loss: 9.5135
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9836 - loss: 0.0386
# Epoch 94: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9834 - loss: 0.0387 - val_accuracy: 0.3408 - val_loss: 9.6160
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9986 - loss: 0.0079
# Epoch 95: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0088 - val_accuracy: 0.3408 - val_loss: 9.6432
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9945 - loss: 0.0128
# Epoch 96: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9946 - loss: 0.0129 - val_accuracy: 0.3408 - val_loss: 9.7764
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9981 - loss: 0.0198
# Epoch 97: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9979 - loss: 0.0199 - val_accuracy: 0.3408 - val_loss: 9.9295
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9924 - loss: 0.0248
# Epoch 98: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9927 - loss: 0.0240 - val_accuracy: 0.3408 - val_loss: 10.0211
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9921 - loss: 0.0144
# Epoch 99: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9920 - loss: 0.0143 - val_accuracy: 0.3408 - val_loss: 10.2461
# Epoch 100/100
# 11/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9943 - loss: 0.0168
# Epoch 100: val_loss did not improve from 1.97258
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9941 - loss: 0.0165 - val_accuracy: 0.3408 - val_loss: 10.1721
#
# Evaluating the model...
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7033 - loss: 1.2922
# Test accuracy: 42.86%

# %% [markdown]
# Visualise the training and validation loss and accuracy

# %%
def visualize_training_metrics(history):
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    train_accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    
    plt.figure(figsize=(12, 6))
    
    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracy, label='Training Accuracy')
    plt.plot(val_accuracy, label='Validation Accuracy')
    plt.title("Training and Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    
    plt.show()

# %%
visualize_training_metrics(history)

# %% [markdown]
# ## Model Evaluation

# %%
test_features, test_masks = test_data

# %% [markdown]
# Evaluate on the entire dataset

# %%
loss, accuracy = sequence_model.evaluate([test_features, test_masks], test_labels, batch_size=32)

print(f"Test Loss: {loss :.4f}")
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7033 - loss: 1.2922
# Test Loss: 1.4963
# Test Accuracy: 42.86%

# %% [markdown]
# ## Model testing

# %% [markdown]
# #### Evaluation with single sample

# %% [markdown]
# Function to prepare the test video

# %%
def prepare_single_video(frames):
    frames = frames[None, ...]
    frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH, ),dtype="bool" )
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    for i, frames_batch in enumerate(frames):
        video_length = frames_batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            frame_features[i, j, :] = feature_extractor.predict(frames_batch[None, j, :])
        frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

    return frame_features, frame_mask

# %% [markdown]
# Make predictions on a single video

# %%
def sequence_prediction(seq_model, frames, true_label):
    frame_features, frame_mask = create_video_mask_and_features(frames)
    probabilities = seq_model.predict([frame_features, frame_mask])[0]
        
    print("\nTop-5 actions:")
    for i in np.argsort(probabilities)[::-1][:5]:
        print(f"  - {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")
    
    # Get the top-1 predicted label (highest probability)
    predicted_index = np.argmax(probabilities)
    predicted_label = class_vocab[predicted_index]

    # Convert true_label to index to align with predicted index format
    true_label_index = class_vocab.index(true_label)

    # Prepare y_true and y_pred as binary arrays (1 for correct label, 0 for others)
    y_true = np.zeros(len(class_vocab))
    y_pred = np.zeros(len(class_vocab))
    y_true[true_label_index] = 1
    y_pred[predicted_index] = 1
 
    return y_true, y_pred, predicted_label

# %% [markdown]
# Display predicted image as GIF

# %%
def display_as_gif(images):
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, duration=100)
    return Image("animation.gif")

# %% [markdown]
# Choosing a random video to use for prediction

# %%
random_index = np.random.randint(len(test_df))

# Get the test video path
test_video = test_df["video_name"].values[random_index]

# Get the true label of the test video
true_label_index = test_labels.tolist()[random_index][0]
true_label = class_vocab[true_label_index]

test_video_frames = load_and_preprocess_video(os.path.join("test", test_video))

print(f"Test video path: {test_video}")
print(f"Label: {true_label}")

print(f"""
Test video frames shape:
  - {test_video_frames.shape[0]} frames
  - {test_video_frames.shape[1]} pixels (height) x {test_video_frames.shape[2]} pixels (width)
  - {test_video_frames.shape[3]} color channels
""")

display_as_gif(test_video_frames[:MAX_SEQ_LENGTH])
# Out:
# Test video path: v_CricketShot_g06_c04.avi
# Label: CricketShot
#
# Test video frames shape:
#   - 135 frames
#   - 224 pixels (height) x 224 pixels (width)
#   - 3 color channels

# %% [markdown]
# Run the prediction on the test video

# %%
y_true, y_pred, predicted_label = sequence_prediction(sequence_model, test_video_frames, true_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
#
# Top-5 actions:
#   - CricketShot: 31.05%
#   - Punch: 26.30%
#   - ShavingBeard: 16.43%
#   - PlayingCello: 14.52%
#   - TennisSwing: 11.70%

# %%
print(f"\nTrue label: {true_label}")
print(f"Predicted label: {predicted_label}")

print(f"y_true: {y_true}")
print(f"y_pred: {y_pred}")
# Out:
# True label: CricketShot
# Predicted label: CricketShot
# y_true: [1. 0. 0. 0. 0.]
# y_pred: [1. 0. 0. 0. 0.]

# %% [markdown]
# Evaluation Metrics

# %%
def display_evaluation_metrics(y_true, y_pred, predictions=None, target_classes=None):
    accuracy = accuracy_score(y_true, y_pred)
    print(f"Top-1 Accuracy: {accuracy * 100:.2f}%")

    # Calculate Top-k accuracy
    if predictions is not None:
        k = 2
        top_k_acc = top_k_accuracy_score(y_true, predictions, k=k)
        print(f"Top-{k} Accuracy: {top_k_acc * 100:.2f}%")
        
        # TODO: Compare these
        # Using TensorFlow's top_k_categorical_accuracy
        # top_k_acc = top_k_categorical_accuracy(y_true, predictions, k=2).numpy().mean()

    report = classification_report(y_true, y_pred, target_names=target_classes, zero_division=0)
    print("Classification Report:\n", report)

# %%
display_evaluation_metrics(y_true, y_pred)
# Out:
# Top-1 Accuracy: 100.00%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         4
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5

# %% [markdown]
# #### Evaluation on the entire test set

# %%
predictions = sequence_model.predict([test_features, test_masks], batch_size=32)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
display_evaluation_metrics(test_labels, predicted_classes, predictions, class_vocab)
# Out:
# Top-1 Accuracy: 42.86%
# Top-2 Accuracy: 58.48%
# Classification Report:
#                precision    recall  f1-score   support
#
#  CricketShot       0.36      1.00      0.53        49
# PlayingCello       0.93      0.95      0.94        44
#        Punch       0.11      0.13      0.12        39
# ShavingBeard       0.00      0.00      0.00        43
#  TennisSwing       0.00      0.00      0.00        49
#
#     accuracy                           0.43       224
#    macro avg       0.28      0.42      0.32       224
# weighted avg       0.28      0.43      0.32       224

# %%
def display_confusion_matrix(y_true, y_pred, target_classes, show_plot=False):
    conf_matrix = confusion_matrix(y_true, y_pred)
    
    if show_plot:
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", xticklabels=target_classes, yticklabels=target_classes)
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.title("Confusion Matrix")
        plt.show()
    else:
        print(conf_matrix)

# %%
true_labels = np.array(test_labels).flatten()
display_confusion_matrix(true_labels, predicted_classes, class_vocab, show_plot=False)
# Out:
# [[49  0  0  0  0]
#  [ 0 42  2  0  0]
#  [34  0  5  0  0]
#  [ 3  3 37  0  0]
#  [49  0  0  0  0]]
